# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.models as models
import math
import cv2
from sklearn.utils import shuffle
import seaborn as sns

# %%
categories = ['train', 'test', 'val', 'auto_test'] # 전처리된 데이터셋을 훈련용, 평가용, 검증용으로 구분
path = 'C:/dataset'
data_dir = path+'/osteoarthritis_aug_class3/'
# device = torch.device('mps:0' if torch.backends.mps.is_available() else 'cpu') # Mac OS
device = torch.device( 'cuda' if torch.cuda.is_available() else 'cpu' )

# %%
import os
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from sklearn.utils import shuffle

# 이미지 전처리 함수들
def resize_image(img, size=(128, 128)):
    return cv2.resize(img, size)

def clahe_image(img):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    return clahe.apply(img)

def normalize_img(img):
    return cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX)

def denoise_img(img):
    return cv2.fastNlMeansDenoising(img, None, 30, 7, 21)

def adjust_gamma(image, gamma=0.5):
    inv_gamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** inv_gamma) * 255 for i in np.arange(256)]).astype("uint8")
    return cv2.LUT(image, table)

def crop_knee(image, crop_height, crop_width):
    h, w = image.shape[:2]
    center = (h // 2, w // 2)
    cropped_img = image[
        center[0] - crop_height // 2 : center[0] + crop_height // 2,
        center[1] - crop_width // 2 : center[1] + crop_width // 2
    ]
    return cropped_img

# # 데이터 증강 설정
# datagen = ImageDataGenerator(
#     rotation_range=5,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     zoom_range=0.1,
#     fill_mode='nearest'
# )

# def augment_images(data_dir, label, augment_count=600, gamma=0.5):
#     label_path = os.path.join(data_dir, 'train', str(label))
#     augmented_dir = os.path.join(label_path, 'augmented')
#     os.makedirs(augmented_dir, exist_ok=True)

#     img_names = os.listdir(label_path)
#     img_names = [name for name in img_names if os.path.isfile(os.path.join(label_path, name))]
#     generated_count = 0

#     while generated_count < augment_count:
#         img_name = np.random.choice(img_names)
#         img_path = os.path.join(label_path, img_name)
#         try:
#             img = load_img(img_path, color_mode='grayscale', target_size=(224, 224))
#             img = img_to_array(img).astype('uint8')
#             img = np.squeeze(img, axis=-1)
#             img = adjust_gamma(img, gamma=gamma)
#             img = np.expand_dims(img, axis=-1)
#             img = np.expand_dims(img, axis=0)

#             for batch in datagen.flow(img, batch_size=1, save_to_dir=augmented_dir, save_prefix='aug', save_format='png'):
#                 generated_count += 1
#                 break
#         except PermissionError:
#             print(f"Permission denied: Unable to access file {img_path}")
#         except Exception as e:
#             print(f"Error processing file {img_path}: {e}")

# %%
def load_data(data_dir):
    images = []
    for img_name in os.listdir(data_dir):
        img_path = os.path.join(data_dir, img_name)
        if os.path.isfile(img_path):
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                img = resize_image(img)
                img = crop_knee(img, 320, 400)
                img = clahe_image(img)
                img = normalize_img(img)
                images.append(img)
    return np.array(images)

def load_and_augment_data(data_dir, label):
    label_path = os.path.join(data_dir, 'train', str(label))
    # augmented_dir = os.path.join(label_path, 'augmented')

    images = []
    for img_name in os.listdir(label_path):
        img_path = os.path.join(label_path, img_name)
        if img_name.endswith('.png') and os.path.isfile(img_path):
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                img = resize_image(img)
                img = crop_knee(img, 320, 400)
                img = clahe_image(img)
                img = normalize_img(img)
                images.append(img)
    
    # if os.path.exists(augmented_dir):
    #     for img_name in os.listdir(augmented_dir):
    #         img_path = os.path.join(augmented_dir, img_name)
    #         if img_name.endswith('.png') and os.path.isfile(img_path):
    #             img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    #             if img is not None:
    #                 img = resize_image(img)
    #                 img = crop_knee(img, 320, 400)
    #                 img = clahe_image(img)
    #                 img = normalize_img(img)
    #                 images.append(img)
    
    return np.array(images)


# 데이터 로딩 및 시각화
category = 'train'
label = 2

if category == 'train' and label == 2:
    images = load_and_augment_data(data_dir, label)
else:
    label_path = os.path.join(data_dir, category, str(label))
    if os.path.isdir(label_path):
        images = load_data(label_path)
    else:
        images = np.array([])

if len(images) > 0:
    random_images = images[np.random.choice(images.shape[0], 5, replace=False)]

    plt.figure(figsize=(10, 5))
    for i, img in enumerate(random_images):
        plt.subplot(1, 5, i + 1)
        plt.imshow(img, cmap='gray')
        plt.axis('off')
    plt.show()
else:
    print("이미지가 없습니다.")

# %%
# 각 카테고리와 라벨에 따라 이미지를 처리
all_data = {}
for category in categories:
    category_path = os.path.join(data_dir, category)
    all_data[category] = {}
    for label in range(3):
        if category == 'train' and label == 2:
            processed_img_list = load_and_augment_data(data_dir, label)
        else:
            label_path = os.path.join(category_path, str(label))
            if os.path.isdir(label_path):
                processed_img_list = load_data(label_path)
            else:
                processed_img_list = np.array([])
        all_data[category][label] = processed_img_list
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[377], line 12
#      10 label_path = os.path.join(category_path, str(label))
#      11 if os.path.isdir(label_path):
# ---> 12     processed_img_list = load_data(label_path)
#      13 else:
#      14     processed_img_list = np.array([])
#
# Cell In[376], line 8, in load_data(data_dir)
#       6 img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#       7 if img is not None:
# ----> 8     img = resize_image(img)
#       9     img = crop_knee(img, 320, 400)
#      10     img = clahe_image(img)
#
# Cell In[375], line 11, in resize_image(img, size)
#      10 def resize_image(img, size=(128, 128)):
# ---> 11     return cv2.resize(img, size)
#
# KeyboardInterrupt:

# %%
# Function to sample 500 images from each label for training
def sample_images(data, num_samples=500):
    sampled_data = []
    sampled_labels = []
    for label, images in data.items():
        if len(images) >= num_samples:
            sampled_data.append(images[:num_samples])
            sampled_labels.append(np.full(num_samples, label))
        else:
            sampled_data.append(images)
            sampled_labels.append(np.full(len(images), label))
    sampled_data = np.concatenate(sampled_data, axis=0)
    sampled_labels = np.concatenate(sampled_labels, axis=0)
    return shuffle(sampled_data, sampled_labels)

# %%
# Sample 500 images
train_data_sampled, train_labels_sampled = sample_images(all_data['train'])
val_data_sampled, val_labels_sampled = sample_images(all_data['val'])
test_data_sampled, test_labels_sampled = sample_images(all_data['test'])

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import DataLoader, TensorDataset

val_data_combined = []
val_labels_combined = []
test_data_combined = []
test_labels_combined = []

for dataset in ['val', 'test']:
    for label, images in all_data[dataset].items():
        if dataset == 'val':
            val_data_combined.append(images)
            val_labels_combined.append(np.full(images.shape[0], label))
        else:
            test_data_combined.append(images)
            test_labels_combined.append(np.full(images.shape[0], label))

val_data_combined = np.concatenate(val_data_combined, axis=0)
val_labels_combined = np.concatenate(val_labels_combined, axis=0)
test_data_combined = np.concatenate(test_data_combined, axis=0)
test_labels_combined = np.concatenate(test_labels_combined, axis=0)
# PyTorch 텐서로 변환
train_data_tensor = torch.tensor(train_data_sampled, dtype=torch.float32)
train_labels_tensor = torch.tensor(train_labels_sampled, dtype=torch.long)
val_data_tensor = torch.tensor(val_data_combined, dtype=torch.float32)
val_labels_tensor = torch.tensor(val_labels_combined, dtype=torch.long)
test_data_tensor = torch.tensor(test_data_combined, dtype=torch.float32)
test_labels_tensor = torch.tensor(test_labels_combined, dtype=torch.long)

# PyTorch 데이터셋 및 데이터 로더 생성
train_dataset = TensorDataset(train_data_tensor, train_labels_tensor)
val_dataset = TensorDataset(val_data_tensor, val_labels_tensor)
test_dataset = TensorDataset(test_data_tensor, test_labels_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
train_data_tensor.shape,train_labels_tensor.shape ,test_data_tensor.shape, test_labels_tensor.shape
# Out:
# (torch.Size([1500, 96, 128]),
#  torch.Size([1500]),
#  torch.Size([1656, 96, 128]),
#  torch.Size([1656]))

# %%
val_data_tensor.shape, test_data_tensor.shape, val_labels_tensor.shape, test_labels_tensor.shape
# Out:
# (torch.Size([826, 96, 128]),
#  torch.Size([1656, 96, 128]),
#  torch.Size([826]),
#  torch.Size([1656]))

# %%
# num_classes = 3

# def get_in_features(model_name):
#     if model_name == 'resnet':
#         model = models.resnet50(pretrained=True)
#         in_features = model.fc.in_features
#     elif model_name == 'densenet':
#         model = models.densenet121(pretrained=True)
#         in_features = model.classifier.in_features
#     elif model_name == 'vgg':
#         model = models.vgg16(pretrained=True)
#         in_features = model.classifier[6].in_features
#     else:
#         raise ValueError('모델 이름 없음.')
#     return in_features

# class CustomResNet(nn.Module):
#     def __init__(self, num_classes, in_features):
#         super(CustomResNet, self).__init__()
#         self.resnet = models.resnet50(pretrained=True)
#         self.resnet.fc = nn.Identity()
#         self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
#         self.dropout = nn.Dropout(0.2)
#         self.fc = nn.Linear(in_features, num_classes)

#     def forward(self, x):
#         x = self.resnet(x)
#         x = self.global_avg_pool(x)
#         x = torch.flatten(x, 1)
#         x = self.dropout(x)
#         x = self.fc(x)
#         return x

# class CustomDenseNet(nn.Module):
#     def __init__(self, num_classes, in_features):
#         super(CustomDenseNet, self).__init__()
#         self.densenet = models.densenet121(pretrained=True)
#         self.densenet.classifier = nn.Identity()
#         self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
#         self.dropout = nn.Dropout(0.2)
#         self.fc = nn.Linear(in_features, num_classes)

#     def forward(self, x):
#         x = self.densenet.features(x)
#         x = self.global_avg_pool(x)
#         x = torch.flatten(x, 1)
#         x = self.dropout(x)
#         x = self.fc(x)
#         return x

# class CustomVGG(nn.Module):
#     def __init__(self, num_classes, in_features):
#         super(CustomVGG, self).__init__()
#         self.vgg = models.vgg16(pretrained=True)
#         self.vgg.classifier = nn.Identity()
#         self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
#         self.dropout = nn.Dropout(0.2)
#         self.fc = nn.Linear(in_features, num_classes)

#     def forward(self, x):
#         x = self.vgg.features(x)
#         x = self.global_avg_pool(x)
#         x = torch.flatten(x, 1)
#         x = self.dropout(x)
#         x = self.fc(x)
#         return x

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from sklearn.metrics import precision_score, recall_score, f1_score

num_classes = 3

def get_pretrained_model(model_name, num_classes):
    if model_name == 'resnet':
        model = models.resnet50(pretrained=True)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
    elif model_name == 'densenet':
        model = models.densenet121(pretrained=True)
        model.classifier = nn.Linear(model.classifier.in_features, num_classes)
    elif model_name == 'mobilenetv2':
        model = models.mobilenet_v2(pretrained=True)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
    elif model_name == 'vgg19':
        model = models.vgg19(pretrained=True)
        model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)
    elif model_name == 'vgg16':
        model = models.vgg16(pretrained=True)
        model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)
    else:
        raise ValueError('Unknown model name')
    
    return model

# 사전학습 모델 설정
criterion = nn.CrossEntropyLoss()
model_name = 'vgg16'
model = get_pretrained_model(model_name, num_classes)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
# Freeze initial layers
for param in model.parameters():
    param.requires_grad = False

if model_name == 'resnet':
    for param in model.fc.parameters():
        param.requires_grad = True
elif model_name == 'densenet':
    for param in model.classifier.parameters():
        param.requires_grad = True
elif model_name == 'vgg16':
    for param in model.classifier[6].parameters():
        param.requires_grad = True
elif model_name == 'vgg19':
    for param in model.classifier[6].parameters():
        param.requires_grad = True
elif model_name == 'mobilenetv2':
    for param in model.classifier[1].parameters():
        param.requires_grad = True


# optimizer = optim.Adam(filter(lambda x: x.requires_grad, model.parameters()), lr=0.001)
optimizer = optim.SGD(filter(lambda x: x.requires_grad, model.parameters()), lr=0.001, momentum=0.9, weight_decay=0.0001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

num_epochs = 30
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    all_train_labels = []
    all_train_predictions = []
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        if inputs.ndim == 3:
            inputs = inputs.unsqueeze(1)
        if inputs.shape[1] == 1:
            inputs = inputs.repeat(1, 3, 1, 1)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
        all_train_labels.extend(labels.cpu().numpy())
        all_train_predictions.extend(predicted.cpu().numpy())
        
        if i % 100 == 99:
            print(f'[Epoch {epoch + 1}, Batch {i + 1}] loss: {running_loss / 100:.3f}')
            running_loss = 0.0

    scheduler.step()

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train
    train_precision = precision_score(all_train_labels, all_train_predictions, average='macro')
    train_recall = recall_score(all_train_labels, all_train_predictions, average='macro')
    train_f1 = f1_score(all_train_labels, all_train_predictions, average='macro')
    
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    all_val_labels = []
    all_val_predictions = []
    with torch.no_grad():
        for data in val_loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            
            if images.ndim == 3:
                images = images.unsqueeze(1)
            if images.shape[1] == 1:
                images = images.repeat(1, 3, 1, 1)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()
            all_val_labels.extend(labels.cpu().numpy())
            all_val_predictions.extend(predicted.cpu().numpy())

    val_loss /= len(val_loader)
    val_accuracy = 100 * correct_val / total_val
    val_precision = precision_score(all_val_labels, all_val_predictions, average='macro')
    val_recall = recall_score(all_val_labels, all_val_predictions, average='macro')
    val_f1 = f1_score(all_val_labels, all_val_predictions, average='macro')
    
    print(f'TEpoch {epoch + 1}, Train loss: {train_loss:.3f}, Train Accuracy: {train_accuracy:.2f}%, '
          f'Train Precision: {train_precision:.2f}, Train Recall: {train_recall:.2f}, Train F1-Score: {train_f1:.2f}')
    print(f'VEpoch {epoch + 1}, Validation loss: {val_loss:.3f}, Validation Accuracy: {val_accuracy:.2f}%, '
          f'Validation Precision: {val_precision:.2f}, Validation Recall: {val_recall:.2f}, Validation F1-Score: {val_f1:.2f}')
    print('학습 끝~')
    print('='*60)
# Out:
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TEpoch 1, Train loss: 58.491, Train Accuracy: 32.87%, Train Precision: 0.33, Train Recall: 0.33, Train F1-Score: 0.33
# VEpoch 1, Validation loss: 91.529, Validation Accuracy: 3.27%, Validation Precision: 0.01, Validation Recall: 0.33, Validation F1-Score: 0.02
# 학습 끝~
# ============================================================
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TEpoch 2, Train loss: 81.473, Train Accuracy: 33.67%, Train Precision: 0.34, Train Recall: 0.34, Train F1-Score: 0.34
# VEpoch 2, Validation loss: 29.169, Validation Accuracy: 11.14%, Validation Precision: 0.05, Validation Recall: 0.30, Validation F1-Score: 0.08
# 학습 끝~
# ============================================================
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TEpoch 3, Train loss: 88.173, Train Accuracy: 36.47%, Train Precision: 0.36, Train Recall: 0.36, Train F1-Score: 0.36
# VEpoch 3, Validation loss: 65.472, Validation Accuracy: 12.83%, Validation Precision: 0.04, Validation Recall: 0.33, Validation F1-Score: 0.08
# 학습 끝~
# ============================================================
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TEpoch 4, Train loss: 92.622, Train Accuracy: 37.20%, Train Precision: 0.37, Train Recall: 0.37, Train F1-Score: 0.37
# VEpoch 4, Validation loss: 125.806, Validation Accuracy: 3.27%, Validation Precision: 0.01, Validation Recall: 0.33, Validation F1-Score: 0.02
# 학습 끝~
# ============================================================
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TEpoch 5, Train loss: 110.077, Train Accuracy: 38.27%, Train Precision: 0.38, Train Recall: 0.38, Train F1-Score: 0.38
# VEpoch 5, Validation loss: 72.739, Validation Accuracy: 12.47%, Validation Precision: 0.04, Validation Recall: 0.32, Validation F1-Score: 0.08
# 학습 끝~
# ============================================================
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TEpoch 6, Train loss: 96.477, Train Accuracy: 40.07%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 6, Validation loss: 13.952, Validation Accuracy: 82.69%, Validation Precision: 0.28, Validation Recall: 0.33, Validation F1-Score: 0.30
# 학습 끝~
# ============================================================
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TEpoch 7, Train loss: 104.146, Train Accuracy: 38.87%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 7, Validation loss: 38.871, Validation Accuracy: 11.74%, Validation Precision: 0.05, Validation Recall: 0.31, Validation F1-Score: 0.08
# 학습 끝~
# ============================================================
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TEpoch 8, Train loss: 84.207, Train Accuracy: 40.27%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 8, Validation loss: 41.198, Validation Accuracy: 11.99%, Validation Precision: 0.05, Validation Recall: 0.32, Validation F1-Score: 0.08
# 학습 끝~
# ============================================================
# TEpoch 9, Train loss: 82.630, Train Accuracy: 40.07%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 9, Validation loss: 9.329, Validation Accuracy: 54.48%, Validation Precision: 0.37, Validation Recall: 0.38, Validation F1-Score: 0.33
# 학습 끝~
# ============================================================
# TEpoch 10, Train loss: 82.278, Train Accuracy: 39.47%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 10, Validation loss: 28.215, Validation Accuracy: 13.08%, Validation Precision: 0.38, Validation Recall: 0.33, Validation F1-Score: 0.09
# 학습 끝~
# ============================================================
# c:\Users\igyuw\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TEpoch 11, Train loss: 80.595, Train Accuracy: 38.20%, Train Precision: 0.38, Train Recall: 0.38, Train F1-Score: 0.38
# VEpoch 11, Validation loss: 43.761, Validation Accuracy: 10.41%, Validation Precision: 0.05, Validation Recall: 0.29, Validation F1-Score: 0.08
# 학습 끝~
# ============================================================
# TEpoch 12, Train loss: 74.690, Train Accuracy: 40.40%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 12, Validation loss: 24.512, Validation Accuracy: 13.80%, Validation Precision: 0.36, Validation Recall: 0.33, Validation F1-Score: 0.10
# 학습 끝~
# ============================================================
# TEpoch 13, Train loss: 73.326, Train Accuracy: 40.33%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 13, Validation loss: 33.368, Validation Accuracy: 12.11%, Validation Precision: 0.38, Validation Recall: 0.32, Validation F1-Score: 0.08
# 학습 끝~
# ============================================================
# TEpoch 14, Train loss: 69.078, Train Accuracy: 40.47%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 14, Validation loss: 25.190, Validation Accuracy: 13.08%, Validation Precision: 0.35, Validation Recall: 0.32, Validation F1-Score: 0.09
# 학습 끝~
# ============================================================
# TEpoch 15, Train loss: 64.994, Train Accuracy: 40.13%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 15, Validation loss: 16.522, Validation Accuracy: 23.24%, Validation Precision: 0.38, Validation Recall: 0.36, Validation F1-Score: 0.17
# 학습 끝~
# ============================================================
# TEpoch 16, Train loss: 66.842, Train Accuracy: 38.80%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 16, Validation loss: 14.348, Validation Accuracy: 28.57%, Validation Precision: 0.38, Validation Recall: 0.38, Validation F1-Score: 0.21
# 학습 끝~
# ============================================================
# TEpoch 17, Train loss: 66.950, Train Accuracy: 39.07%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 17, Validation loss: 12.438, Validation Accuracy: 33.66%, Validation Precision: 0.37, Validation Recall: 0.38, Validation F1-Score: 0.24
# 학습 끝~
# ============================================================
# TEpoch 18, Train loss: 62.011, Train Accuracy: 41.27%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 18, Validation loss: 19.822, Validation Accuracy: 16.83%, Validation Precision: 0.37, Validation Recall: 0.33, Validation F1-Score: 0.12
# 학습 끝~
# ============================================================
# TEpoch 19, Train loss: 60.603, Train Accuracy: 43.67%, Train Precision: 0.44, Train Recall: 0.44, Train F1-Score: 0.44
# VEpoch 19, Validation loss: 17.793, Validation Accuracy: 20.10%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.15
# 학습 끝~
# ============================================================
# TEpoch 20, Train loss: 64.768, Train Accuracy: 38.93%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 20, Validation loss: 22.772, Validation Accuracy: 14.16%, Validation Precision: 0.37, Validation Recall: 0.33, Validation F1-Score: 0.10
# 학습 끝~
# ============================================================
# TEpoch 21, Train loss: 68.235, Train Accuracy: 39.47%, Train Precision: 0.40, Train Recall: 0.39, Train F1-Score: 0.40
# VEpoch 21, Validation loss: 15.799, Validation Accuracy: 23.61%, Validation Precision: 0.38, Validation Recall: 0.36, Validation F1-Score: 0.17
# 학습 끝~
# ============================================================
# TEpoch 22, Train loss: 65.543, Train Accuracy: 39.33%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 22, Validation loss: 16.287, Validation Accuracy: 22.28%, Validation Precision: 0.38, Validation Recall: 0.36, Validation F1-Score: 0.16
# 학습 끝~
# ============================================================
# TEpoch 23, Train loss: 66.595, Train Accuracy: 38.13%, Train Precision: 0.38, Train Recall: 0.38, Train F1-Score: 0.38
# VEpoch 23, Validation loss: 17.831, Validation Accuracy: 19.61%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 24, Train loss: 66.322, Train Accuracy: 40.47%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 24, Validation loss: 16.907, Validation Accuracy: 21.31%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.16
# 학습 끝~
# ============================================================
# TEpoch 25, Train loss: 60.501, Train Accuracy: 42.53%, Train Precision: 0.43, Train Recall: 0.43, Train F1-Score: 0.43
# VEpoch 25, Validation loss: 18.369, Validation Accuracy: 18.40%, Validation Precision: 0.37, Validation Recall: 0.34, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 26, Train loss: 63.288, Train Accuracy: 40.67%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 26, Validation loss: 18.632, Validation Accuracy: 18.04%, Validation Precision: 0.37, Validation Recall: 0.34, Validation F1-Score: 0.13
# 학습 끝~
# ============================================================
# TEpoch 27, Train loss: 61.657, Train Accuracy: 43.00%, Train Precision: 0.43, Train Recall: 0.43, Train F1-Score: 0.43
# VEpoch 27, Validation loss: 18.736, Validation Accuracy: 17.92%, Validation Precision: 0.37, Validation Recall: 0.34, Validation F1-Score: 0.13
# 학습 끝~
# ============================================================
# TEpoch 28, Train loss: 63.302, Train Accuracy: 42.20%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 28, Validation loss: 17.587, Validation Accuracy: 20.34%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.15
# 학습 끝~
# ============================================================
# TEpoch 29, Train loss: 61.292, Train Accuracy: 42.93%, Train Precision: 0.43, Train Recall: 0.43, Train F1-Score: 0.43
# VEpoch 29, Validation loss: 17.640, Validation Accuracy: 20.22%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.15
# 학습 끝~
# ============================================================
# TEpoch 30, Train loss: 63.882, Train Accuracy: 39.00%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 30, Validation loss: 17.696, Validation Accuracy: 20.10%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.15
# 학습 끝~
# ============================================================
# TEpoch 31, Train loss: 62.440, Train Accuracy: 42.00%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 31, Validation loss: 17.763, Validation Accuracy: 20.10%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.15
# 학습 끝~
# ============================================================
# TEpoch 32, Train loss: 65.454, Train Accuracy: 39.27%, Train Precision: 0.40, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 32, Validation loss: 17.934, Validation Accuracy: 19.98%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.15
# 학습 끝~
# ============================================================
# TEpoch 33, Train loss: 61.655, Train Accuracy: 42.60%, Train Precision: 0.43, Train Recall: 0.43, Train F1-Score: 0.43
# VEpoch 33, Validation loss: 18.015, Validation Accuracy: 19.98%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.15
# 학습 끝~
# ============================================================
# TEpoch 34, Train loss: 61.961, Train Accuracy: 41.40%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 34, Validation loss: 17.956, Validation Accuracy: 19.98%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.15
# 학습 끝~
# ============================================================
# TEpoch 35, Train loss: 61.609, Train Accuracy: 40.67%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 35, Validation loss: 18.101, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 36, Train loss: 63.513, Train Accuracy: 39.73%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 36, Validation loss: 18.109, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 37, Train loss: 62.633, Train Accuracy: 42.00%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 37, Validation loss: 18.127, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 38, Train loss: 64.234, Train Accuracy: 40.60%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 38, Validation loss: 18.130, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 39, Train loss: 62.928, Train Accuracy: 41.67%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 39, Validation loss: 18.131, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 40, Train loss: 63.125, Train Accuracy: 40.87%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 40, Validation loss: 18.130, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 41, Train loss: 66.520, Train Accuracy: 41.87%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 41, Validation loss: 18.125, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 42, Train loss: 65.195, Train Accuracy: 39.93%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 42, Validation loss: 18.134, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 43, Train loss: 64.159, Train Accuracy: 40.07%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 43, Validation loss: 18.134, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 44, Train loss: 62.280, Train Accuracy: 41.27%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 44, Validation loss: 18.134, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 45, Train loss: 63.331, Train Accuracy: 39.73%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 45, Validation loss: 18.134, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 46, Train loss: 61.265, Train Accuracy: 42.73%, Train Precision: 0.43, Train Recall: 0.43, Train F1-Score: 0.43
# VEpoch 46, Validation loss: 18.134, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 47, Train loss: 64.169, Train Accuracy: 40.93%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 47, Validation loss: 18.135, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 48, Train loss: 63.808, Train Accuracy: 41.53%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 48, Validation loss: 18.135, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 49, Train loss: 62.353, Train Accuracy: 40.73%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 49, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 50, Train loss: 63.528, Train Accuracy: 39.60%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 50, Validation loss: 18.135, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 51, Train loss: 62.996, Train Accuracy: 40.60%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 51, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 52, Train loss: 63.035, Train Accuracy: 40.93%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 52, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 53, Train loss: 61.002, Train Accuracy: 40.93%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 53, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 54, Train loss: 60.359, Train Accuracy: 42.20%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 54, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 55, Train loss: 65.263, Train Accuracy: 39.93%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 55, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 56, Train loss: 65.332, Train Accuracy: 39.27%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 56, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 57, Train loss: 66.167, Train Accuracy: 38.80%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 57, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 58, Train loss: 64.358, Train Accuracy: 39.47%, Train Precision: 0.40, Train Recall: 0.39, Train F1-Score: 0.40
# VEpoch 58, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 59, Train loss: 67.647, Train Accuracy: 38.87%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 59, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 60, Train loss: 65.819, Train Accuracy: 39.60%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 60, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 61, Train loss: 63.418, Train Accuracy: 39.80%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 61, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 62, Train loss: 68.204, Train Accuracy: 38.47%, Train Precision: 0.38, Train Recall: 0.38, Train F1-Score: 0.38
# VEpoch 62, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 63, Train loss: 58.975, Train Accuracy: 41.47%, Train Precision: 0.42, Train Recall: 0.41, Train F1-Score: 0.42
# VEpoch 63, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 64, Train loss: 65.213, Train Accuracy: 40.47%, Train Precision: 0.41, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 64, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 65, Train loss: 64.775, Train Accuracy: 41.47%, Train Precision: 0.42, Train Recall: 0.41, Train F1-Score: 0.42
# VEpoch 65, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 66, Train loss: 60.444, Train Accuracy: 41.33%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 66, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 67, Train loss: 67.239, Train Accuracy: 37.27%, Train Precision: 0.37, Train Recall: 0.37, Train F1-Score: 0.37
# VEpoch 67, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 68, Train loss: 62.025, Train Accuracy: 42.60%, Train Precision: 0.43, Train Recall: 0.43, Train F1-Score: 0.43
# VEpoch 68, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 69, Train loss: 61.810, Train Accuracy: 39.47%, Train Precision: 0.40, Train Recall: 0.39, Train F1-Score: 0.40
# VEpoch 69, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 70, Train loss: 62.302, Train Accuracy: 41.53%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 70, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 71, Train loss: 63.904, Train Accuracy: 41.67%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 71, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 72, Train loss: 62.828, Train Accuracy: 40.73%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 72, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 73, Train loss: 61.886, Train Accuracy: 39.53%, Train Precision: 0.39, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 73, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 74, Train loss: 63.536, Train Accuracy: 41.13%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 74, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 75, Train loss: 65.186, Train Accuracy: 40.13%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 75, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 76, Train loss: 62.422, Train Accuracy: 42.87%, Train Precision: 0.43, Train Recall: 0.43, Train F1-Score: 0.43
# VEpoch 76, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 77, Train loss: 61.679, Train Accuracy: 42.27%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 77, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 78, Train loss: 65.381, Train Accuracy: 40.47%, Train Precision: 0.41, Train Recall: 0.40, Train F1-Score: 0.41
# VEpoch 78, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 79, Train loss: 63.556, Train Accuracy: 40.00%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 79, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 80, Train loss: 64.381, Train Accuracy: 41.13%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 80, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 81, Train loss: 62.727, Train Accuracy: 39.40%, Train Precision: 0.40, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 81, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 82, Train loss: 62.256, Train Accuracy: 40.53%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 82, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 83, Train loss: 61.742, Train Accuracy: 41.40%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 83, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 84, Train loss: 60.551, Train Accuracy: 43.07%, Train Precision: 0.43, Train Recall: 0.43, Train F1-Score: 0.43
# VEpoch 84, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 85, Train loss: 65.957, Train Accuracy: 38.40%, Train Precision: 0.38, Train Recall: 0.38, Train F1-Score: 0.38
# VEpoch 85, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 86, Train loss: 62.545, Train Accuracy: 42.07%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 86, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 87, Train loss: 61.262, Train Accuracy: 41.60%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 87, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 88, Train loss: 62.144, Train Accuracy: 40.53%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 88, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 89, Train loss: 63.408, Train Accuracy: 41.27%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 89, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 90, Train loss: 65.017, Train Accuracy: 39.67%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 90, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 91, Train loss: 63.514, Train Accuracy: 42.67%, Train Precision: 0.43, Train Recall: 0.43, Train F1-Score: 0.43
# VEpoch 91, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 92, Train loss: 59.004, Train Accuracy: 42.20%, Train Precision: 0.42, Train Recall: 0.42, Train F1-Score: 0.42
# VEpoch 92, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 93, Train loss: 60.684, Train Accuracy: 42.47%, Train Precision: 0.43, Train Recall: 0.42, Train F1-Score: 0.43
# VEpoch 93, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 94, Train loss: 61.732, Train Accuracy: 41.33%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 94, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 95, Train loss: 64.584, Train Accuracy: 39.93%, Train Precision: 0.40, Train Recall: 0.40, Train F1-Score: 0.40
# VEpoch 95, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 96, Train loss: 57.397, Train Accuracy: 43.53%, Train Precision: 0.43, Train Recall: 0.44, Train F1-Score: 0.44
# VEpoch 96, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 97, Train loss: 64.884, Train Accuracy: 40.67%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 97, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 98, Train loss: 67.270, Train Accuracy: 38.60%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 98, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 99, Train loss: 64.524, Train Accuracy: 41.20%, Train Precision: 0.41, Train Recall: 0.41, Train F1-Score: 0.41
# VEpoch 99, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================
# TEpoch 100, Train loss: 65.213, Train Accuracy: 38.53%, Train Precision: 0.39, Train Recall: 0.39, Train F1-Score: 0.39
# VEpoch 100, Validation loss: 18.136, Validation Accuracy: 19.49%, Validation Precision: 0.38, Validation Recall: 0.35, Validation F1-Score: 0.14
# 학습 끝~
# ============================================================

# %%
# Testing phase
model.eval()
correct = 0
total = 0
all_labels = []
all_predictions = []
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        
        # Ensure images have the correct shape (N, C, H, W) and convert grayscale to RGB
        if images.ndim == 3:
            images = images.unsqueeze(1)  # Add channel dimension if missing
        if images.shape[1] == 1:
            images = images.repeat(1, 3, 1, 1)
        
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

test_accuracy = 100 * correct / total
test_precision = precision_score(all_labels, all_predictions, average='macro')
test_recall = recall_score(all_labels, all_predictions, average='macro')
test_f1 = f1_score(all_labels, all_predictions, average='macro')

print(f'Test Accuracy: {test_accuracy:.2f}%, Test Precision: {test_precision:.2f}, '
      f'Test Recall: {test_recall:.2f}, Test F1-Score: {test_f1:.2f}')
# Out:
# Test Accuracy: 18.54%, Test Precision: 0.35, Test Recall: 0.33, Test F1-Score: 0.13

# %%
from sklearn.metrics import confusion_matrix

# Confusion matrix
conf_matrix = confusion_matrix(all_labels, all_predictions)
print('Confusion Matrix:')
print(conf_matrix)

# Plotting confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# # 0 : 639
# # 1 : 296
# # 2 : 447
# # 3 : 223
# # 4 : 51
# Out:
# Confusion Matrix:
# [[ 104 1201   77]
#  [  11  202   10]
#  [   1   49    1]]

# %%
# # Define the number of output classes
# num_classes = 5

# # Load pre-trained models and modify the final layer for transfer learning
# def get_pretrained_model(model_name, num_classes):
#     if model_name == 'resnet':
#         model = models.resnet18(pretrained=True)
#         model.fc = nn.Linear(model.fc.in_features, num_classes)
#     elif model_name == 'densenet':
#         model = models.densenet121(pretrained=True)
#         model.classifier = nn.Linear(model.classifier.in_features, num_classes)
#     elif model_name == 'vgg':
#         model = models.vgg16(pretrained=True)
#         model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)
#     else:
#         raise ValueError('Unknown model name')
    
#     return model

# # 사전학습 모델 설정
# model_name = 'resnet'  # or 'densenet' or 'vgg'
# model = get_pretrained_model(model_name, num_classes)
# model = model.to(device)

# # Freeze initial layers
# for param in model.parameters():
#     param.requires_grad = False

# # Unfreeze the last layer
# if model_name == 'resnet':
#     for param in model.fc.parameters():
#         param.requires_grad = True
# elif model_name == 'densenet':
#     for param in model.classifier.parameters():
#         param.requires_grad = True
# elif model_name == 'vgg':
#     for param in model.classifier[6].parameters():
#         param.requires_grad = True

# # Redefine optimizer to update only the last layer
# optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

# # Training loop (same as before)
# num_epochs = 30
# for epoch in range(num_epochs):
#     model.train()
#     running_loss = 0.0
#     for i, data in enumerate(train_loader, 0):
#         inputs, labels = data
#         inputs, labels = inputs.to(device), labels.to(device)
#         inputs = inputs.unsqueeze(1)  # Add channel dimension for grayscale images
#         optimizer.zero_grad()
#         outputs = model(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()
#         if i % 100 == 99:
#             print(f'[Epoch {epoch + 1}, Batch {i + 1}] loss: {running_loss / 100:.3f}')
#             running_loss = 0.0

#     model.eval()
#     val_loss = 0.0
#     correct = 0
#     total = 0
#     with torch.no_grad():
#         for data in val_loader:
#             images, labels = data
#             inputs, labels = inputs.to(device), labels.to(device)
#             images = images.unsqueeze(1)
#             outputs = model(images)
#             loss = criterion(outputs, labels)
#             val_loss += loss.item()
#             _, predicted = torch.max(outputs.data, 1)
#             total += labels.size(0)
#             correct += (predicted == labels).sum().item()

#     print(f'Epoch {epoch + 1}, Validation loss: {val_loss / len(val_loader):.3f}, Accuracy: {100 * correct / total:.2f}%')

# print('Training complete')

# # Testing phase (same as before)
# model.eval()
# correct = 0
# total = 0
# with torch.no_grad():
#     for data in test_loader:
#         images, labels = data
#         inputs, labels = inputs.to(device), labels.to(device)
#         outputs = model(images)
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

# print(f'Test Accuracy: {100 * correct / total:.2f}%')

# %%
# # 테스트 단계
# model.eval()
# correct = 0
# total = 0
# with torch.no_grad():
#     for data in test_loader:
#         images, labels = data
#         inputs, labels = inputs.to(device), labels.to(device)
#         outputs = model(images)
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

# print(f'Test Accuracy: {100 * correct / total:.2f}%')
